# %%
from lsdb_custom_graphs import lsdb

# %%
from distributed import Client

# with Client() as c:
lsdb.open_catalog("../tests/data/small_sky_order1_collection").compute()
# Out:
#                       id     ra   dec  ra_error  dec_error
# _healpix_29
# 3187422220182231470  707  308.5 -69.5         0          0
# 3187796123455121090  792  320.5 -69.5         0          0
# ...                  ...    ...   ...       ...        ...
# 3400255793565258227  767  314.5 -29.5         0          0
# 3424180623569024089  743  307.5 -25.5         0          0
#
# [131 rows x 5 columns]

# %%
cat = lsdb.open_catalog("../tests/data/small_sky_order1_collection")
cat
# Out:
# LSDB expr Catalog(operation=FromHealpixMap(read_pixel)) Schema:
# Empty NestedFrame
# Columns: [id, ra, dec, ra_error, dec_error]
# Index: []

# %%
cat.operation
# Out:
# FromHealpixMap(read_pixel)

# %%
cat[["id"]]
# Out:
# LSDB expr Catalog(operation=MapPartitions(class_func)) Schema:
# Empty NestedFrame
# Columns: [id]
# Index: []

# %%
cat[["id"]].operation.handle_column_projection.__dict__
# Out:
# {'_projection_type': lsdb_custom_graphs.lsdb.ops.projections.ColumnProjection}

# %%
sources = lsdb.open_catalog("../tests/data/small_sky_source")
sources
# Out:
# LSDB expr Catalog(operation=FromHealpixMap(read_pixel)) Schema:
# Empty NestedFrame
# Columns: [source_id, source_ra, source_dec, mjd, mag, band, object_id, object_ra, object_dec]
# Index: []

# %%
cat.crossmatch(sources).operation.build().graph
# Out:
# /Users/smcmu/code/custom-graphs/src/lsdb_custom_graphs/lsdb/catalog.py:218: FutureWarning: The default suffix behavior will change from applying suffixes to all columns to only applying suffixes to overlapping columns in a future release.To maintain the current behavior, explicitly set `suffix_method='all_columns'`. To change to the new behavior, set `suffix_method='overlapping_columns'`.
#   warnings.warn(
# /Users/smcmu/code/custom-graphs/src/lsdb_custom_graphs/lsdb/crossmatch_catalog_data.py:478: RuntimeWarning: Right catalog does not have a margin cache. Results may be incomplete and/or inaccurate.
#   warnings.warn(
# {('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   3): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 3) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   9): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 9) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   6): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 6) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   2): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 2) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   5): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 5) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   11): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 11) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   8): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 8) perform_crossmatch(...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   3): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 3) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   9): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 9) read_pixel(..., ...)>,
#  ('read_pixel-eedeae3fb73d898006f42d5f52044dcc',
#   0): <Task ('read_pixel-eedeae3fb73d898006f42d5f52044dcc', 0) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   6): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 6) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   12): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 12) read_pixel(..., ...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   0): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 0) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   12): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 12) perform_crossmatch(...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   7): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 7) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   1): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 1) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   4): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 4) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   10): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 10) read_pixel(..., ...)>,
#  ('read_pixel-eedeae3fb73d898006f42d5f52044dcc',
#   1): <Task ('read_pixel-eedeae3fb73d898006f42d5f52044dcc', 1) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   13): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 13) read_pixel(..., ...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   4): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 4) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   1): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 1) perform_crossmatch(...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   7): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 7) perform_crossmatch(...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   2): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 2) read_pixel(..., ...)>,
#  ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0',
#   10): <Task ('perform_crossmatch-fc624e7857181b008aa6cfc38b126ba0', 10) perform_crossmatch(...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   5): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 5) read_pixel(..., ...)>,
#  ('read_pixel-eedeae3fb73d898006f42d5f52044dcc',
#   2): <Task ('read_pixel-eedeae3fb73d898006f42d5f52044dcc', 2) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   8): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 8) read_pixel(..., ...)>,
#  ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1',
#   11): <Task ('read_pixel-6c140b017ccfd5b4f355b6b85a0a27c1', 11) read_pixel(..., ...)>,
#  ('read_pixel-eedeae3fb73d898006f42d5f52044dcc',
#   3): <Task ('read_pixel-eedeae3fb73d898006f42d5f52044dcc', 3) read_pixel(..., ...)>}
